# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
a=pd.Series([4,7,-5,3])
a
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
a.array
# Out:
# <PandasArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
g=pd.Series([1,2,3,4],index=["b","c","a","d"])
g
# Out:
# b    1
# c    2
# a    3
# d    4
# dtype: int64

# %%
g["d"]=6
g
# Out:
# b    1
# c    2
# a    3
# d    6
# dtype: int64

# %%
sdata={"Ohio":35000,"Texas":71000,"Punjab":16000,"Haryana":5000}
s3=pd.Series(sdata)

# %%
s3.to_dict()
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Punjab': 16000, 'Haryana': 5000}

# %%
states=["Punjab","Haryana","MP","Ohio"]
s4=pd.Series(sdata,index=states)
s4
# Out:
# Punjab     16000.0
# Haryana     5000.0
# MP             NaN
# Ohio       35000.0
# dtype: float64

# %%
import pandas as pd
from pandas import Series

g=pd.Series([1,2,3,4],index=["b","a","c","d"])
print(g)

print(g["a"])
print(g[3])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 4

# %%
pd.isna(s4)
# Out:
# Punjab     False
# Haryana    False
# MP          True
# Ohio       False
# dtype: bool

# %%
pd.notna(s4)
# Out:
# Punjab      True
# Haryana     True
# MP         False
# Ohio        True
# dtype: bool

# %%
#Name Roll No. Reg No. Parent Contact Student Contact
data={"state":["Ohio","ohio","ohio","Punjab","Punjab","Punjab"],"year":[2001,2000,2002,2003,2003,2004],"stats":[1.5,1.7,3.6,2.4,2.9,3.2]}
f1=pd.DataFrame(data)
f1
# Out:
#     state  year  stats
# 0    Ohio  2001    1.5
# 1    ohio  2000    1.7
# 2    ohio  2002    3.6
# 3  Punjab  2003    2.4
# 4  Punjab  2003    2.9
# 5  Punjab  2004    3.2

# %%
f1.head()
# Out:
#     state  year  stats
# 0    Ohio  2001    1.5
# 1    ohio  2000    1.7
# 2    ohio  2002    3.6
# 3  Punjab  2003    2.4
# 4  Punjab  2003    2.9

# %%
f1.tail()
# Out:
#     state  year  stats
# 1    ohio  2000    1.7
# 2    ohio  2002    3.6
# 3  Punjab  2003    2.4
# 4  Punjab  2003    2.9
# 5  Punjab  2004    3.2

# %%
f2=pd.DataFrame(data,columns=["stats","year","state","literacy_rate"])

# %%
f2=pd.DataFrame(data)
f2.columns
# Out:
# Index(['state', 'year', 'stats'], dtype='object')

# %% [markdown]
# Doubt by student
#
# > Add blockquote

# %%
import numpy as np
c=np.arange(2.0,2.6,0.1)
print(c)
b=np.arange(2.0,2.5,0.1)
print(b)
# Out:
# [2.  2.1 2.2 2.3 2.4 2.5 2.6]
# [2.  2.1 2.2 2.3 2.4]

# %%
a=np.arange(2.0,2.8,0.1)
print(a)

# %%
f2.loc[1]
# Out:
# stats             1.7
# year             2000
# state            ohio
# literacy_rate     NaN
# Name: 1, dtype: object

# %%
f2.iloc[2]
# Out:
# stats             3.6
# year             2002
# state            ohio
# literacy_rate     NaN
# Name: 2, dtype: object

# %%
f2["literacy_rate"]=1.5
f2
# Out:
#    stats  year   state  literacy_rate
# 0    1.5  2001    Ohio            1.5
# 1    1.7  2000    ohio            1.5
# 2    3.6  2002    ohio            1.5
# 3    2.4  2003  Punjab            1.5
# 4    2.9  2003  Punjab            1.5
# 5    3.2  2004  Punjab            1.5

# %%
f2["literacy_rate"]=np.arange(6.)
f2
# Out:
#    stats  year   state  literacy_rate
# 0    1.5  2001    Ohio            0.0
# 1    1.7  2000    ohio            1.0
# 2    3.6  2002    ohio            2.0
# 3    2.4  2003  Punjab            3.0
# 4    2.9  2003  Punjab            4.0
# 5    3.2  2004  Punjab            5.0

# %%
f2.loc[[0,1,2,3]]
# Out:
#    stats  year   state  literacy_rate
# 0    1.5  2001    Ohio            1.5
# 1    1.7  2000    ohio            1.5
# 2    3.6  2002    ohio            1.5
# 3    2.4  2003  Punjab            1.5

# %%
f2.loc[1,'year']
# Out:
# 2000

# %%
f2.iloc[[0,3]]
# Out:
#    stats  year   state  literacy_rate
# 0    1.5  2001    Ohio            1.5
# 3    2.4  2003  Punjab            1.5

# %%
val=pd.Series([-1.2,-1.5,-1.7],index=["two","four","five"])
f2["literacy_rate"]=val
f2
# Out:
#    stats  year   state  literacy_rate  Literacy_rate
# 0    1.5  2001    Ohio            NaN            NaN
# 1    1.7  2000    ohio            NaN            NaN
# 2    3.6  2002    ohio            NaN            NaN
# 3    2.4  2003  Punjab            NaN            NaN
# 4    2.9  2003  Punjab            NaN            NaN
# 5    3.2  2004  Punjab            NaN            NaN

# %%
f2["pqr"]=f2["state"]=="ohio"
f2
# Out:
#    stats  year   state  literacy_rate  Literacy_rate    pqr
# 0    1.5  2001    Ohio            NaN            NaN  False
# 1    1.7  2000    ohio            NaN            NaN   True
# 2    3.6  2002    ohio            NaN            NaN   True
# 3    2.4  2003  Punjab            NaN            NaN  False
# 4    2.9  2003  Punjab            NaN            NaN  False
# 5    3.2  2004  Punjab            NaN            NaN  False

# %%
del f2["pqr"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pqr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
f2.columns
# Out:
# Index(['stats', 'year', 'state', 'literacy_rate', 'Literacy_rate'], dtype='object')

# %%
del f2["Literacy_rate"]

# %%
f2.columns
# Out:
# Index(['stats', 'year', 'state', 'literacy_rate'], dtype='object')

# %%
p={"Punjab":{2000:1.5,2001:1.7,2002:3.6}, "Haryana":{2001:2.4,2002:2.9}}
f3=pd.DataFrame(p)
f3
# Out:
#       Punjab  Haryana
# 2000     1.5      NaN
# 2001     1.7      2.4
# 2002     3.6      2.9

# %%
f3.T
# Out:
#          2000  2001  2002
# Punjab    1.5   1.7   3.6
# Haryana   NaN   2.4   2.9

# %%
pd.DataFrame(p,index=[2001,2002,2003])
# Out:
#       Punjab  Haryana
# 2001     1.7      2.4
# 2002     3.6      2.9
# 2003     NaN      NaN

# %%
f3.index.name="year"
f3.columns.name="state"
f3
# Out:
# state  Punjab  Haryana
# year
# 2000      1.5      NaN
# 2001      1.7      2.4
# 2002      3.6      2.9

# %%
o1=pd.Series(np.arange(3),index=["a","b","c"])
o1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
o1.index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
o1.index["b"]="d"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-26eff2947570> in <cell line: 1>()
# ----> 1 o1.index["b"]="d"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    5155     @final
#    5156     def __setitem__(self, key, value):
# -> 5157         raise TypeError("Index does not support mutable operations")
#    5158
#    5159     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
l=pd.Index(np.arange(3))
l
# Out:
# Index([0, 1, 2], dtype='int64')

# %%
o2=pd.Series([1.5,2,2.5],index=l)
o2
# Out:
# 0    1.5
# 1    2.0
# 2    2.5
# dtype: float64

# %%
o2.index is l
# Out:
# True

# %% [markdown]
# Index methods
# append
# difference
# intersection
# union
# isin
# delete
# drop
# insert
# is_monotonic
# is_unique
# unique()

# %%
o4=pd.Series([1,2,5,7,4,9,6],index=["d","p","r","t","a","b","c"])
o4
# Out:
# d    1
# p    2
# r    5
# t    7
# a    4
# b    9
# c    6
# dtype: int64

# %%
o5=o4.reindex(["a","b","c","d","e","p","r","t"])

# %%
o5
# Out:
# a    4.0
# b    9.0
# c    6.0
# d    1.0
# e    NaN
# p    2.0
# r    5.0
# t    7.0
# dtype: float64

# %%
o5.ffill()
# Out:
# a    4.0
# b    9.0
# c    6.0
# d    1.0
# e    1.0
# p    2.0
# r    5.0
# t    7.0
# dtype: float64

# %% [markdown]
#    A   B  C
# 0  NaN 11 NaN
# 1 1   5    5
# 2 2   NaN   10
# 3 3 NaN    11

# %%
p={"A":{1:1,2:2,3:3}, "B":{0:11,1:5},"c":{1:5,2:10,3:11}}
f3=pd.DataFrame(p)
f3=f3.ffill()
print(f3)
# Out:
#      A     B     c
# 1  1.0   5.0   5.0
# 2  2.0   5.0  10.0
# 3  3.0   5.0  11.0
# 0  3.0  11.0  11.0

# %%
p={"A":{0:np.nan,1:1,2:2,3:3}, "B":{0:11,1:5},"c":{1:5,2:10,3:11}}
f3=pd.DataFrame(p)
f3.reindex([0,1,2,3])
f3=f3.bfill()
f3=f3.ffill()
print(f3)
# Out:
#      A     B     c
# 0  1.0  11.0   5.0
# 1  1.0   5.0   5.0
# 2  2.0   5.0  10.0
# 3  3.0   5.0  11.0

# %%
o6=pd.Series(["red","yellow","green"],index=[0,2,4])
o6
# Out:
# 0       red
# 2    yellow
# 4     green
# dtype: object

# %%
o6.reindex(np.arange(6),method="bfill")
# Out:
# 0       red
# 1    yellow
# 2    yellow
# 3     green
# 4     green
# 5       NaN
# dtype: object

# %%
o9=pd.Series(np.arange(5.),index=["a","b","c","d","e"])
o9
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
o9.drop("b")
# Out:
# a    0.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64
