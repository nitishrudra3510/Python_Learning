# %%
import pandas as pd
titanic_data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %% [markdown]
# Inspecting thr data

# %%
titanic_data.head() # this will provides the first 5 inputs.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.tail() # it provides the last 5 val.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_data.shape # prints the no of column and rows
# Out:
# (891, 12)

# %%
# this provides us statistical data..
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data.info() # provides the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# we extracted statistical information of only object data Types..
titanic_data.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# Accessing the column

# %%
titanic_data.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic_data["Name"] # acessing the column from another method.
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# # Finding unique values from each column.

# %%
# this method calculates the no. of unique values frm each column.
titanic_data.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # Find the count of unique values from each column

# %%
titanic_data["Pclass"].value_counts().head()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# # Finding statitics for rach specific column

# %%
titanic_data["Name"].mode()

#if any name appears more than once, it will be shown as the mode. If no name repeats, it will return an empty Series.
# Out:
# 0                        Abbing, Mr. Anthony
# 1                Abbott, Mr. Rossmore Edward
# 2           Abbott, Mrs. Stanton (Rosa Hunt)
# 3                        Abelson, Mr. Samuel
# 4      Abelson, Mrs. Samuel (Hannah Wizosky)
#                        ...
# 886                  de Mulder, Mr. Theodore
# 887                de Pelsmaeker, Mr. Alfons
# 888                del Carlo, Mr. Sebastiano
# 889          van Billiard, Mr. Austin Blyler
# 890              van Melkebeke, Mr. Philemon
# Name: Name, Length: 891, dtype: object

# %%
titanic_data["Fare"].mean() # /average of fare coluumn.
# Out:
# 32.204207968574636

# %% [markdown]
# # Selecting Rows and Columns

# %% [markdown]
# selecting multiples columns

# %%
titanic_data[["Name","Fare", "Sex"]]
# Out:
#                                                   Name     Fare     Sex
# 0                              Braund, Mr. Owen Harris   7.2500    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833  female
# 2                               Heikkinen, Miss. Laina   7.9250  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000  female
# 4                             Allen, Mr. William Henry   8.0500    male
# ..                                                 ...      ...     ...
# 886                              Montvila, Rev. Juozas  13.0000    male
# 887                       Graham, Miss. Margaret Edith  30.0000  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500  female
# 889                              Behr, Mr. Karl Howell  30.0000    male
# 890                                Dooley, Mr. Patrick   7.7500    male
#
# [891 rows x 3 columns]

# %% [markdown]
# # using.loc[] for label-based selection

# %%
titanic_data.loc[0:5,["Name", "Fare"]] # it is taking only category data.
# Out:
#                                                 Name     Fare
# 0                            Braund, Mr. Owen Harris   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                             Heikkinen, Miss. Laina   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                           Allen, Mr. William Henry   8.0500
# 5                                   Moran, Mr. James   8.4583

# %% [markdown]
# # Loc: It is used for only category datas(object,float), etc.

# %%
titanic_data.loc[10, :] ### for selecting a row of values for a specific row and getting all the values of columns
# Out:
# PassengerId                                 11
# Survived                                     1
# Pclass                                       3
# Name           Sandstrom, Miss. Marguerite Rut
# Sex                                     female
# Age                                        4.0
# SibSp                                        1
# Parch                                        1
# Ticket                                 PP 9549
# Fare                                      16.7
# Cabin                                       G6
# Embarked                                     S
# Name: 10, dtype: object

# %%
# for selecting all the columns values of a specific column
titanic_data.loc[:, "Fare"]

# same as titanic_data["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# # Using Iloc[] for integer based slection

# %%
titanic_data.iloc[1:10, 0:3] # [rows, column]
# Out:
#                                                 Name  PassengerId  Survived
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
# 5                                   Moran, Mr. James            6         0
# 6                            McCarthy, Mr. Timothy J            7         0
# 7                     Palsson, Master. Gosta Leonard            8         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)           10         1

# %%
# this is temporary because we did not use inplace=True
titanic_data.set_index("Name").head(3)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
#
#                                                               Ticket     Fare  \
# Name
# ...

# %%
titanic_data.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# now it is permanent.
titanic_data.set_index(["Name"], inplace=True)

# %%
titanic_data.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %% [markdown]
# # Reset Index

# %%
titanic_data.reset_index(inplace=True)

# %%
titanic_data
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %% [markdown]
# # Data Cleaning..
# Handling any missing value.

# %%
titanic_data.isna()
# Out:
#       Name  PassengerId  Survived  Pclass    Sex    Age  SibSp  Parch  Ticket  \
# 0    False        False     False   False  False  False  False  False   False
# 1    False        False     False   False  False  False  False  False   False
# 2    False        False     False   False  False  False  False  False   False
# 3    False        False     False   False  False  False  False  False   False
# 4    False        False     False   False  False  False  False  False   False
# ..     ...          ...       ...     ...    ...    ...    ...    ...     ...
# 886  False        False     False   False  False  False  False  False   False
# 887  False        False     False   False  False  False  False  False   False
# 888  False        False     False   False  False   True  False  False   False
# 889  False        False     False   False  False  False  False  False   False
# 890  False        False     False   False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# # counting the no of null values in each column.

# %%
titanic_data.isnull().sum()
# Out:
# Name             0
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Filling the values where it is null
#
#
# As for Categorical data we can fill the data with a value if we have any, if not we can prefer the mode.
#
# Mean imputation is often used when the missing values are numerical and the distribution of the variable is approximately normal.
#
# Median imputation is preferred when the distribution is skewed, as the median is less sensitive to outliers than the mean

# %%
# Filling the values where it is null

# in the dataset we have numberical values missing so we find mean data..
mean_data = titanic_data["Age"].mean()
print(mean_data)
# Out:
# 29.69911764705882

# %%
# filling the mean data whenever it is missing. in the age columns..
df = titanic_data["Age"].fillna(mean_data, inplace=True)

# %%
titanic_data.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# now verifying the data
titanic_data.isnull().sum()
# Out:
# Name             0
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # now for categorical data missing

# %%
titanic_data.Cabin #titanic_data["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %% [markdown]
# # now we can either go for mode or drop data i prefer dropping the unecessary
